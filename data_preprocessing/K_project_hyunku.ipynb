# %% [markdown]
# <a href="https://colab.research.google.com/github/baeksumin/k-project/blob/main/K_project_hyunku.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
1. 저장된 fullcode 목록을 불러와서 종목별 데이터 수집
2. pickle 저장

(프로젝트를 시작할 때 1번만 실행)
'''
# Out:
# '\n1. 저장된 fullcode 목록을 불러와서 종목별 데이터 수집\n2. pickle 저장\n\n(프로젝트를 시작할 때 1번만 실행)\n'

# %%
import json
import requests
import pandas as pd
from io import BytesIO
from datetime import datetime 
from datetime import timedelta
import pickle
from google.colab import drive

drive.mount('/content/drive')
output_path = '/content/drive/MyDrive/k-project/output/'
data_path = '/content/drive/MyDrive/[Shared]K-Project/data/'
# pickle 경로를 설정하기 위해
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 한국시간 설정
import pytz

KST = pytz.timezone('Asia/Seoul')
today = str(datetime.now(KST).strftime("%Y%m%d"))
print(today)
# Out:
# 20211015

# %%
## Load pickle - fullcode 목록
with open(data_path + 'full_code.pkl',"rb") as f: 
    fullcode = pickle.load(f)
fullcode
# Out:
#          full_code short_code   codeName marketEngName status
# 0     KR7060310000     060310         3S        KOSDAQ     상장
# 1     KR7095570008     095570     AJ네트웍스         KOSPI     상장
# 2     KR7006840003     006840      AK홀딩스         KOSPI     상장
# 3     KR7054620000     054620     APS홀딩스        KOSDAQ     상장
# 4     KR7265520007     265520      AP시스템        KOSDAQ     상장
# ...            ...        ...        ...           ...    ...
# 2588  KR7388220006     388220  하나금융19호스팩        KOSDAQ     상장
# 2589  KR7376290003     376290       씨유테크        KOSDAQ     상장
# 2590  KR7381970003     381970        케이카         KOSPI     상장
# 2591  KR7393210000     393210     토마토시스템         KONEX     상장
# 2592  KR7391710001     391710  엔에이치스팩21호        KOSDAQ     상장
#
# [2593 rows x 5 columns]

# %%
#상장폐지 상태 제외시키기.
fullcode_filter = fullcode[fullcode['status'] != '상장폐지']
fullcode_filter
# Out:
#          full_code short_code   codeName marketEngName status
# 0     KR7060310000     060310         3S        KOSDAQ     상장
# 1     KR7095570008     095570     AJ네트웍스         KOSPI     상장
# 2     KR7006840003     006840      AK홀딩스         KOSPI     상장
# 3     KR7054620000     054620     APS홀딩스        KOSDAQ     상장
# 4     KR7265520007     265520      AP시스템        KOSDAQ     상장
# ...            ...        ...        ...           ...    ...
# 2588  KR7388220006     388220  하나금융19호스팩        KOSDAQ     상장
# 2589  KR7376290003     376290       씨유테크        KOSDAQ     상장
# 2590  KR7381970003     381970        케이카         KOSPI     상장
# 2591  KR7393210000     393210     토마토시스템         KONEX     상장
# 2592  KR7391710001     391710  엔에이치스팩21호        KOSDAQ     상장
#
# [2588 rows x 5 columns]

# %%
fullcode_list = list(fullcode_filter['full_code'])
print(fullcode_list[:10])
# fullcode열을 list로 변경 후 확인
# Out:
# ['KR7060310000', 'KR7095570008', 'KR7006840003', 'KR7054620000', 'KR7265520007', 'KR7211270004', 'KR7027410000', 'KR7282330000', 'KR7138930003', 'KR7001460005']

# %%
'''
종가 시가 저가 고가 시가총액 EPS PER BPS PBR 주당배당금 배당수익률
(* 필요한 컬럼)

df2
 0   TRD_DD : 거래일자 *
 1   ISU_CD : 종목코드 *      
 2   ISU_NM : 종목명 *      
 3   MKT_NM : 시장코드 (kospi)      
 4   SECUGRP_NM : 증권구분 (주권)    
 5   TDD_CLSPRC : 종가 *  
 6   FLUC_TP_CD    
 7   CMPPRVDD_PRC : 대비 
 8   FLUC_RT : 등락률      
 9   TDD_OPNPRC : 시가 *  
 10  TDD_HGPRC  : 고가 *  
 11  TDD_LWPRC  : 저가 *  
 12  ACC_TRDVOL : 거래량   
 13  ACC_TRDVAL : 거래대금   
 14  MKTCAP : 시가총액 *

df3
 0   TRD_DD : 거래일자        
 1   TDD_CLSPRC : 종가    
 2   FLUC_TP_CD     
 3   CMPPREVDD_PRC : 대비 
 4   FLUC_RT : 등락률      
 5   EPS *           
 6   PER *           
 7   BPS *           
 8   PBR *           
 9   DPS : 주당배당금 *          
 10  DVD_YLD : 배당수익률 *
 '''
# Out:
# '\n종가 시가 저가 고가 시가총액 EPS PER BPS PBR 주당배당금 배당수익률\n(* 필요한 컬럼)\n\ndf2\n 0   TRD_DD : 거래일자 *\n 1   ISU_CD : 종목코드 *      \n 2   ISU_NM : 종목명 *      \n 3   MKT_NM : 시장코드 (kospi)      \n 4   SECUGRP_NM : 증권구분 (주권)    \n 5   TDD_CLSPRC : 종가 *  \n 6   FLUC_TP_CD    \n 7   CMPPRVDD_PRC : 대비 \n 8   FLUC_RT : 등락률      \n 9   TDD_OPNPRC : 시가 *  \n 10  TDD_HGPRC  : 고가 *  \n 11  TDD_LWPRC  : 저가 *  \n 12  ACC_TRDVOL : 거래량   \n 13  ACC_TRDVAL : 거래대금   \n 14  MKTCAP : 시가총액 *\n\ndf3\n 0   TRD_DD : 거래일자        \n 1   TDD_CLSPRC : 종가    \n 2   FLUC_TP_CD     \n 3   CMPPREVDD_PRC : 대비 \n 4   FLUC_RT : 등락률      \n 5   EPS *           \n 6   PER *           \n 7   BPS *           \n 8   PBR *           \n 9   DPS : 주당배당금 *          \n 10  DVD_YLD : 배당수익률 *\n '

# %%
url2 = 'http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd'
headers = {'User-Agent': 'Chrome/78.0.3904.87 Safari/537.36',}

strtDd = '19000101'
endDd = today

for i in fullcode_list[:2]: # 테스트를 위해 2개만 실행 (두 종목만 출력됨)
    data2 = { 'bld': 'dbms/MDC/STAT/issue/MDCSTAT23902',
    'isuCd': i,
    'isuCd2': '',
    'strtDd': strtDd,
    'endDd': endDd,
    'share': '1',
    'money': '1',
    'csvxls_isNo': 'false',}

    r2 = requests.post(url2, data2, headers)
    j2 = json.loads(r2.text)
    df2=pd.DataFrame(j2['output'])
    # print(df2)
    # print('------------------------------------------------')

    data3 = { 'bld': 'dbms/MDC/STAT/standard/MDCSTAT03502',
    'isuCd': i,
    'isuCd2': i,
    'strtDd': strtDd,
    'endDd': endDd,
    'searchType': '2',
    'mktId': 'ALL',
    'csvxls_isNo': 'false',}

    r2 = requests.post(url2, data3, headers)
    j2 = json.loads(r2.text)
    df3=pd.DataFrame(j2['output'])
    # print(df3)
    # print('------------------------------------------------')

    df2_ = df2[['TRD_DD', 'ISU_CD', 'ISU_NM', 'TDD_CLSPRC', 'TDD_OPNPRC', 'TDD_HGPRC', 'TDD_LWPRC', 'MKTCAP']]
    df3_ = df3[['TRD_DD', 'EPS', 'PER', 'BPS', 'PBR', 'DPS', 'DVD_YLD']]

    result = pd.merge(df2_, df3_)
    print(result)
    print('------------------------------------------------')
# Out:
#           TRD_DD  ISU_CD  ISU_NM TDD_CLSPRC  ...  BPS   PBR DPS DVD_YLD
# 0     2021/10/15  060310      3S      4,065  ...  792  5.13   0    0.00
# 1     2021/10/14  060310      3S      3,995  ...  792  5.04   0    0.00
# 2     2021/10/13  060310      3S      3,790  ...  792  4.79   0    0.00
# 3     2021/10/12  060310      3S      3,745  ...  792  4.73   0    0.00
# 4     2021/10/08  060310      3S      3,790  ...  792  4.79   0    0.00
# ...          ...     ...     ...        ...  ...  ...   ...  ..     ...
# 4812  2002/04/29  060310  삼에스코리아      6,780  ...    -     -   -       -
# 4813  2002/04/26  060310  삼에스코리아      7,700  ...    -     -   -       -
# 4814  2002/04/25  060310  삼에스코리아      8,750  ...    -     -   -       -
# 4815  2002/04/24  060310  삼에스코리아      8,510  ...    -     -   -       -
# 4816  2002/04/23  060310  삼에스코리아      7,600  ...    -     -   -       -
#
# [4817 rows x 14 columns]
# ------------------------------------------------
#           TRD_DD  ISU_CD  ISU_NM TDD_CLSPRC  ...     BPS   PBR  DPS DVD_YLD
# 0     2021/10/15  095570  AJ네트웍스      5,660  ...   6,089  0.93  210    3.71
# 1     2021/10/14  095570  AJ네트웍스      5,670  ...   6,089  0.93  210    3.70
# 2     2021/10/13  095570  AJ네트웍스      5,720  ...   6,089  0.94  210    3.67
# 3     2021/10/12  095570  AJ네트웍스      5,660  ...   6,089  0.93  210    3.71
# 4     2021/10/08  095570  AJ네트웍스      5,690  ...   6,089  0.93  210    3.69
# ...          ...     ...     ...        ...  ...     ...   ...  ...     ...
# 1506  2015/08/27  095570  AJ네트웍스     37,850  ...  23,715  1.60    0    0.00
# 1507  2015/08/26  095570  AJ네트웍스     35,450  ...  23,715  1.49    0    0.00
# 1508  2015/08/25  095570  AJ네트웍스     31,100  ...  23,715  1.31    0    0.00
# 1509  2015/08/24  095570  AJ네트웍스     32,400  ...  23,715  1.37    0    0.00
# 1510  2015/08/21  095570  AJ네트웍스     35,500  ...  23,715  1.50    0    0.00
#
# [1511 rows x 14 columns]
# ------------------------------------------------

# %%
## Save pickle
# with open(output_path + "df2.pickle","wb") as fw:
#     pickle.dump(df2, fw)

# %%
#talib 설치
# !wget -q http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz 2>&1 > /dev/null
# !tar xvzf ta-lib-0.4.0-src.tar.gz 2>&1 > /dev/null

import os

os.chdir('ta-lib')  

# !./configure --prefix=/usr 2>&1 > /dev/null
# !make 2>&1 > /dev/null
# !make install 2>&1 > /dev/null

os.chdir('../')

# !pip install TA-Lib 2>&1 > /dev/null
# Out:
# ./configure: line 4354: /usr/bin/file: No such file or directory

# %%
import talib
import numpy as np

# %%
result
# Out:
#           TRD_DD  ISU_CD  ISU_NM TDD_CLSPRC  ...     BPS   PBR  DPS DVD_YLD
# 0     2021/10/15  095570  AJ네트웍스      5,660  ...   6,089  0.93  210    3.71
# 1     2021/10/14  095570  AJ네트웍스      5,670  ...   6,089  0.93  210    3.70
# 2     2021/10/13  095570  AJ네트웍스      5,720  ...   6,089  0.94  210    3.67
# 3     2021/10/12  095570  AJ네트웍스      5,660  ...   6,089  0.93  210    3.71
# 4     2021/10/08  095570  AJ네트웍스      5,690  ...   6,089  0.93  210    3.69
# ...          ...     ...     ...        ...  ...     ...   ...  ...     ...
# 1506  2015/08/27  095570  AJ네트웍스     37,850  ...  23,715  1.60    0    0.00
# 1507  2015/08/26  095570  AJ네트웍스     35,450  ...  23,715  1.49    0    0.00
# 1508  2015/08/25  095570  AJ네트웍스     31,100  ...  23,715  1.31    0    0.00
# 1509  2015/08/24  095570  AJ네트웍스     32,400  ...  23,715  1.37    0    0.00
# 1510  2015/08/21  095570  AJ네트웍스     35,500  ...  23,715  1.50    0    0.00
#
# [1511 rows x 14 columns]

# %%
#최신 데이터가 뒤로 오도록 정렬
result = result.sort_values(by=['TRD_DD'])
result.set_index('TRD_DD',drop=True,inplace=True)
result.reset_index('TRD_DD',drop=False,inplace=True)
result
# Out:
#           TRD_DD  ISU_CD  ISU_NM TDD_CLSPRC  ...     BPS   PBR  DPS DVD_YLD
# 0     2015/08/21  095570  AJ네트웍스     35,500  ...  23,715  1.50    0    0.00
# 1     2015/08/24  095570  AJ네트웍스     32,400  ...  23,715  1.37    0    0.00
# 2     2015/08/25  095570  AJ네트웍스     31,100  ...  23,715  1.31    0    0.00
# 3     2015/08/26  095570  AJ네트웍스     35,450  ...  23,715  1.49    0    0.00
# 4     2015/08/27  095570  AJ네트웍스     37,850  ...  23,715  1.60    0    0.00
# ...          ...     ...     ...        ...  ...     ...   ...  ...     ...
# 1506  2021/10/08  095570  AJ네트웍스      5,690  ...   6,089  0.93  210    3.69
# 1507  2021/10/12  095570  AJ네트웍스      5,660  ...   6,089  0.93  210    3.71
# 1508  2021/10/13  095570  AJ네트웍스      5,720  ...   6,089  0.94  210    3.67
# 1509  2021/10/14  095570  AJ네트웍스      5,670  ...   6,089  0.93  210    3.70
# 1510  2021/10/15  095570  AJ네트웍스      5,660  ...   6,089  0.93  210    3.71
#
# [1511 rows x 14 columns]

# %%
result.columns
# Out:
# Index(['TRD_DD', 'ISU_CD', 'ISU_NM', 'TDD_CLSPRC', 'TDD_OPNPRC', 'TDD_HGPRC',
#        'TDD_LWPRC', 'MKTCAP', 'EPS', 'PER', 'BPS', 'PBR', 'DPS', 'DVD_YLD'],
#       dtype='object')

# %%
#데이터프레임 콤마(,) 제거 그리고 타입 소수로 변환
result['TDD_CLSPRC'] = result['TDD_CLSPRC'].str.replace(',','').astype('float')
result['TDD_OPNPRC'] = result['TDD_OPNPRC'].str.replace(',','').astype('float')
result['TDD_HGPRC'] = result['TDD_HGPRC'].str.replace(',','').astype('float')
result['TDD_LWPRC'] = result['TDD_LWPRC'].str.replace(',','').astype('float')
result['MKTCAP'] = result['MKTCAP'].str.replace(',','').astype('float')
result['BPS'] = result['BPS'].str.replace(',','').astype('float')
result
# Out:
#           TRD_DD  ISU_CD  ISU_NM  TDD_CLSPRC  ...      BPS   PBR  DPS  DVD_YLD
# 0     2015/08/21  095570  AJ네트웍스     35500.0  ...  23715.0  1.50    0     0.00
# 1     2015/08/24  095570  AJ네트웍스     32400.0  ...  23715.0  1.37    0     0.00
# 2     2015/08/25  095570  AJ네트웍스     31100.0  ...  23715.0  1.31    0     0.00
# 3     2015/08/26  095570  AJ네트웍스     35450.0  ...  23715.0  1.49    0     0.00
# 4     2015/08/27  095570  AJ네트웍스     37850.0  ...  23715.0  1.60    0     0.00
# ...          ...     ...     ...         ...  ...      ...   ...  ...      ...
# 1506  2021/10/08  095570  AJ네트웍스      5690.0  ...   6089.0  0.93  210     3.69
# 1507  2021/10/12  095570  AJ네트웍스      5660.0  ...   6089.0  0.93  210     3.71
# 1508  2021/10/13  095570  AJ네트웍스      5720.0  ...   6089.0  0.94  210     3.67
# 1509  2021/10/14  095570  AJ네트웍스      5670.0  ...   6089.0  0.93  210     3.70
# 1510  2021/10/15  095570  AJ네트웍스      5660.0  ...   6089.0  0.93  210     3.71
#
# [1511 rows x 14 columns]

# %% [markdown]
# ##feature engineering

# %% [markdown]
# 단기이평선(50일), 장기이평선(200일) 생성
# 이평선의 종류는 굉장히 다양. 적응형이평선, 이평선 등등 매우 많지만 기본형으로 세팅함.

# %% [markdown]
# 이평선,RSI,ROC,Stochastic,Hammer,HangingMan,DCC 추출

# %%
#Feature Engineering 함수
#그러나 각 생성마다 timeperiod에 대한 최적화가 필요하다. (유전자알고리즘의 사용??)
def feature_engineering(df):
  df['50_MA'] = talib.MA(df['TDD_CLSPRC'],timeperiod=50,matype=0)
  df['200_MA'] = talib.MA(df['TDD_CLSPRC'],timeperiod=200,matype=0)
  df['50_MA'] = df['50_MA'].fillna(method='bfill')
  df['200_MA'] = df['200_MA'].fillna(method='bfill')
  df['RSI'] = talib.RSI(df['TDD_CLSPRC'],timeperiod=14)
  df['RSI'] = df['RSI'].fillna(method='bfill')
  df['ROC'] = talib.ROC(df['TDD_CLSPRC'],timeperiod=10)
  df['ROC'] = df['ROC'].fillna(method='bfill')
  df['Stochastic'], df['Stochastic_MA'] = talib.STOCH(df['TDD_HGPRC'],df['TDD_LWPRC'],df['TDD_CLSPRC'])
  df['Stochastic'] = df['Stochastic'].fillna(method='bfill')
  df['Stochastic_MA'] = df['Stochastic_MA'].fillna(method='bfill')
  df['Hammer'] = talib.CDLHAMMER(df['TDD_OPNPRC'],df['TDD_HGPRC'],df['TDD_LWPRC'],df['TDD_CLSPRC'])
  df['HangingMan'] = talib.CDLHANGINGMAN(df['TDD_OPNPRC'],df['TDD_HGPRC'],df['TDD_LWPRC'],df['TDD_CLSPRC'])
  df['DCC'] = talib.CDLDARKCLOUDCOVER(df['TDD_OPNPRC'],df['TDD_HGPRC'],df['TDD_LWPRC'],df['TDD_CLSPRC'])

# %%
feature_engineering(result)

# %%
result
# Out:
#           TRD_DD  ISU_CD  ISU_NM  ...  Hammer  HangingMan  DCC
# 0     2015/08/21  095570  AJ네트웍스  ...       0           0    0
# 1     2015/08/24  095570  AJ네트웍스  ...       0           0    0
# 2     2015/08/25  095570  AJ네트웍스  ...       0           0    0
# 3     2015/08/26  095570  AJ네트웍스  ...       0           0    0
# 4     2015/08/27  095570  AJ네트웍스  ...       0           0    0
# ...          ...     ...     ...  ...     ...         ...  ...
# 1506  2021/10/08  095570  AJ네트웍스  ...       0           0    0
# 1507  2021/10/12  095570  AJ네트웍스  ...       0           0    0
# 1508  2021/10/13  095570  AJ네트웍스  ...       0           0    0
# 1509  2021/10/14  095570  AJ네트웍스  ...       0           0    0
# 1510  2021/10/15  095570  AJ네트웍스  ...       0           0    0
#
# [1511 rows x 23 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15,10))
plt.plot(result['50_MA'],'b-',label='50MA')
plt.plot(result['200_MA'],'r-',label='200MA')
plt.plot(result['TDD_CLSPRC'],'y-',label='Close')
plt.legend()
plt.show()

# %%
#골든크로스 함수
def death_golden_cross(df):
  first_cross = 0 
  for i in range(0, len(result)):
    if df['50_MA'][i] < df['200_MA'][i] and first_cross == 0:
      print('Death cross on day', df['TRD_DD'][i], ':expect the price to continue to fall')
      first_cross=1
    elif df['50_MA'][i] > df['200_MA'][i] and first_cross ==1:
      print('Golden cross on day', df['TRD_DD'][i], ':expect the price to continue to rise')
      first_cross=0

# %%
death_golden_cross(result)
# Out:
# Death cross on day 2016/03/22 :expect the price to continue to fall
# Golden cross on day 2017/11/06 :expect the price to continue to rise
# Death cross on day 2018/04/11 :expect the price to continue to fall
# Golden cross on day 2019/04/17 :expect the price to continue to rise
# Death cross on day 2019/08/19 :expect the price to continue to fall
# Golden cross on day 2020/02/20 :expect the price to continue to rise
# Death cross on day 2020/03/16 :expect the price to continue to fall
# Golden cross on day 2020/11/17 :expect the price to continue to rise

# %%
#코드 맨 앞 주석 떼었다 붙였다 하면서 해머와 행잉맨 비교해보자.
result[(result['Hammer'] != 0) & (result['HangingMan'] == 0)] #해머인 것만 표시. 해머일 때 주식 매수하기 매우 좋은 타이밍. 해머일 떄 100으로 출력
#result[(result['HangingMan'] != 0) & (result['Hammer'] == 0)] #행잉맨인 것만 표시. 행잉맨일 때는 주식 매도하자. 행잉맨 일 때 -100으로 출력
# Out:
#           TRD_DD  ISU_CD  ISU_NM  ...  Hammer  HangingMan  DCC
# 43    2015/10/26  095570  AJ네트웍스  ...     100           0    0
# 50    2015/11/04  095570  AJ네트웍스  ...     100           0    0
# 57    2015/11/13  095570  AJ네트웍스  ...     100           0    0
# 87    2015/12/28  095570  AJ네트웍스  ...     100           0    0
# 140   2016/03/18  095570  AJ네트웍스  ...     100           0    0
# 174   2016/05/10  095570  AJ네트웍스  ...     100           0    0
# 284   2016/10/19  095570  AJ네트웍스  ...     100           0    0
# 359   2017/02/06  095570  AJ네트웍스  ...     100           0    0
# 373   2017/02/24  095570  AJ네트웍스  ...     100           0    0
# 544   2017/11/09  095570  AJ네트웍스  ...     100           0    0
# 570   2017/12/15  095570  AJ네트웍스  ...     100           0    0
# 571   2017/12/18  095570  AJ네트웍스  ...     100           0    0
# 604   2018/02/06  095570  AJ네트웍스  ...     100           0    0
# 673   2018/05/21  095570  AJ네트웍스  ...     100           0    0
# 676   2018/05/25  095570  AJ네트웍스  ...     100           0    0
# 686   2018/06/11  095570  AJ네트웍스  ...     100           0    0
# 699   2018/06/29  095570  AJ네트웍스  ...     100           0    0
# 736   2018/08/22  095570  AJ네트웍스  ...     100           0    0
# 738   2018/08/24  095570  AJ네트웍스  ...     100           0    0
# 773   2018/10/19  095570  AJ네트웍스  ...     100           0    0
# 775   2018/10/23  095570  AJ네트웍스  ...     100           0    0
# 874   2019/03/20  095570  AJ네트웍스  ...     100           0    0
# 894   2019/04/17  095570  AJ네트웍스  ...     100           0    0
# 956   2019/07/17  095570  AJ네트웍스  ...     100           0    0
# 963   2019/07/26  095570  AJ네트웍스  ...     100           0    0
# 977   2019/08/16  095570  AJ네트웍스  ...     100           0    0
# 981   2019/08/22  095570  AJ네트웍스  ...     100           0    0
# 1071  2020/01/06  095570  AJ네트웍스  ...     100           0    0
# 1100  2020/02/18  095570  AJ네트웍스  ...     100           0    0
# 1115  2020/03/10  095570  AJ네트웍스  ...     100           0    0
# 1132  2020/04/02  095570  AJ네트웍스  ...     100           0    0
# 1144  2020/04/21  095570  AJ네트웍스  ...     100           0    0
# 1156  2020/05/12  095570  AJ네트웍스  ...     100           0    0
# 1177  2020/06/10  095570  AJ네트웍스  ...     100           0    0
# 1212  2020/07/29  095570  AJ네트웍스  ...     100           0    0
# 1309  2020/12/18  095570  AJ네트웍스  ...     100           0    0
# 1328  2021/01/19  095570  AJ네트웍스  ...     100           0    0
# 1357  2021/03/04  095570  AJ네트웍스  ...     100           0    0
# 1497  2021/09/24  095570  AJ네트웍스  ...     100           0    0
#
# [39 rows x 23 columns]

# %%
plt.figure(figsize=(15,10))
plt.plot(result['Hammer'],'b.',label='Hammer')
plt.plot(result['HangingMan'],'r.',label='HangingMan')
plt.xlabel('Date',fontsize=20)
plt.legend()
plt.show()

# %%
#Moving Average Envelope 함수
def MAP(df,use_time):
  UL = []
  ML = []
  LL = []
  MovingAverage = talib.MA(df['TDD_CLSPRC'],timeperiod=use_time)
  MovingAverage = MovingAverage.fillna(method='bfill')
  for i in MovingAverage:
    uls = i + (.07 * i)
    lls = i - (.07 * i)
    mls = i
    UL.append(uls)
    ML.append(mls)
    LL.append(lls)
  return UL, ML, LL

# %%
ul,ml,ll = MAP(result,50)

# %%
plt.figure(figsize=(15,10))
plt.plot(ul,'r',label='UL')
plt.plot(ml,'k',label='ML')
plt.plot(ll,'b',label='LL')
plt.legend()
plt.show()

# %% [markdown]
# 여기까지 작업완성본.
#
# 밑부터는 임시로 막 작성하는 코드
#
# 보통 ARIMA/SARIMA 알고리즘을 사용할때 사용하는 방법론
#
# ctrl + / = 주석처리

# %%
# result['TRD_DD'] = pd.to_datetime(result['TRD_DD'])

# %%
# result['TRD_DD']

# %%
# result.set_index('TRD_DD',drop=True,inplace=True)
# result

# %%
# result = result.asfreq('D',method='ffill')
# result.sort_index(inplace=True)

# %%
# import seaborn as sns
# import statsmodels.api as sm
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# sm.tsa.seasonal_decompose(result['TDD_CLSPRC'],model='addictive').plot()

# %%
# result.reset_index('TRD_DD',drop=False,inplace=True)
# result

# %%
# new_df = result[['TRD_DD','MKTCAP']]
# new_df.set_index('TRD_DD',drop=True,inplace=True)
# new_df

# %%
#연습용 코드(사용X)
def trend_plot(df,timeperiod):
  avg_mktcap = []
  sum = 0
  for i in range(1,len(df) + 1):
    if (i % timeperiod) != 0:
      sum += df['MKTCAP'][i-1]
    elif (i % timeperiod) == 0:
      sum += df['MKTCAP'][i-1]
      avg_mktcap.append(sum/timeperiod)
      sum = 0
  return avg_mktcap

# %%
#시가총액 trend코드. trend의 범위 너무 광범위 -> moving average를 trend로 인식하여 구현.
def show_mktcap_trend(df,usetime):
  trend = df['MKTCAP'].rolling(usetime).mean()
  trend.fillna(method='bfill',inplace=True)
  plt.figure(figsize=(15,10))
  plt.plot(df['MKTCAP'],'b-',label='MKTCAP')
  plt.plot(trend,'r-',label='MKTCAP_TREND')
  plt.legend()
  plt.show()

# %%
show_mktcap_trend(result,50)

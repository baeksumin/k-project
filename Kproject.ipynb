# %% [markdown]
# <a href="https://colab.research.google.com/github/baeksumin/k-project/blob/main/Kproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from datetime import datetime, timedelta
import json
import requests
import pandas as pd
from io import BytesIO
from datetime import datetime

headers={'User-Agent': 'Chrome/93.0.4577.63 Safari/537.36'}

data={'mktId': 'ALL',
        'typeNo':'0',
        'searchText':'',
        'bld': 'dbms/comm/finder/finder_stkisu'}

url="http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"

r=requests.post(url, data, headers=headers)
j = json.loads(r.text)
df=pd.json_normalize(j['block1'])

df

# %%
#날짜
now=datetime.now()
today=now.strftime("%Y%m%d")


day_1 = now + timedelta(days=1)
tomorrow = day_1.strftime("%Y%m%d")
day_2 = now - timedelta(days=1)
yesterday = day_2.strftime("%Y%m%d")

print("오늘:",today);
print("내일:",tomorrow);
print("어제:", yesterday);

# %%
#초기 수집데이터
strDd='19000101'
endDd=today

df = df.set_index('short_code')
full_code = df.loc['005930']['full_code']

data2={'bld': 'dbms/MDC/STAT/standard/MDCSTAT01701',
       'isuCd': full_code,
       'isuCd2': full_code,
       'strtDd': strDd,
       'endDd': endDd,
       'searchType':'2',
       'mktld':'ALL',
       'csvxls_isNo': 'false',
       'share': 1,
       'money': 1}


url2="http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"

r2=requests.post(url2, data2, headers)
j2=json.loads(r2.text)
df3=pd.DataFrame(j2['output'])
df3

# %%
strDd=today
endDd=today

df3 = df3.set_index('short_code')
full_code = df3.loc['005930']['full_code']

data2={'bld': 'dbms/MDC/STAT/standard/MDCSTAT01701',
       'isuCd': full_code,
       'isuCd2': full_code,
       'strtDd': strDd,
       'endDd': endDd,
       'searchType':'2',
       'mktld':'ALL',
       'csvxls_isNo': 'false',
       'share': 1,
       'money': 1}


url2="http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"

r2=requests.post(url2, data2, headers)
j2=json.loads(r2.text)
df3=pd.DataFrame(j2['output'])
df3

# %%
#매일 업데이트 데이터
#pip install schedule

import schedule
import time

#def job():
    strDd=today
    endDd=today

    df = df.set_index('short_code')
    full_code = df.loc['005930']['full_code']

    data2={'bld': 'dbms/MDC/STAT/standard/MDCSTAT01701',
        'isuCd': full_code,
        'isuCd2': full_code,
        'strtDd': strDd,
        'endDd': endDd,
        'searchType':'2',
        'mktld':'ALL',
        'csvxls_isNo': 'false',
        'share': 1,
        'money': 1}


    url2="http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"

    r2=requests.post(url2, data2, headers)
    j2=json.loads(r2.text)
    df3=pd.DataFrame(j2['output'])
df3
#if df3.iloc[0,0]:
#    break
#else:
#{ with open('df3.pickle','wb') as fw:
# pickle.dump(df3, fw)}

# %%
#구글드라이브 연동
from os import path
from google.colab import drive 
drive.mount('/content/drive')
res_path = '/content/drive/MyDrive/K-project/output/'

# %%
#1초기데이터
from datetime import datetime, timedelta
import json
import requests
import pandas as pd
import pickle
from os import path
from google.colab import drive 
from io import BytesIO
from datetime import datetime

#날짜
now=datetime.now()
today=now.strftime("%Y%m%d")


day_1 = now + timedelta(days=1)
tomorrow = day_1.strftime("%Y%m%d")
day_2 = now - timedelta(days=1)
yesterday = day_2.strftime("%Y%m%d")

headers={'User-Agent': 'Chrome/93.0.4577.63 Safari/537.36'}

data={'mktId': 'ALL',
        'typeNo':'0',
        'searchText':'',
        'bld': 'dbms/comm/finder/finder_stkisu'}

url="http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"

r=requests.post(url, data, headers=headers)
j = json.loads(r.text)
df=pd.json_normalize(j['block1'])

#pickle 저장
with open(res_path + 'df.pickle','wb') as fw:
    pickle.dump(df, fw)

strDd='19000101'
endDd=today

df = df.set_index('short_code')
full_code = df.loc['005930']['full_code']

data2={'bld': 'dbms/MDC/STAT/standard/MDCSTAT01701',
       'isuCd': full_code,
       'isuCd2': full_code,
       'strtDd': strDd,
       'endDd': endDd,
       'searchType':'2',
       'mktld':'ALL',
       'csvxls_isNo': 'false',
       'share': 1,
       'money': 1}


url2="http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"

r2=requests.post(url2, data2, headers)
j2=json.loads(r2.text)
df3=pd.DataFrame(j2['output'])

#pickle 저장
with open(res_path + 'df3.pickle','wb') as fw:
    pickle.dump(df3, fw)

# %%
#2 매일 업데이트
from datetime import datetime, timedelta
import schedule
import time
import json
import requests
import pandas as pd
import pickle
from os import path
from google.colab import drive 
from io import BytesIO
from datetime import datetime

schedule.every().day.at("24:00").do(job)

#날짜
now=datetime.now()
today=now.strftime("%Y%m%d")


day_1 = now + timedelta(days=1)
tomorrow = day_1.strftime("%Y%m%d")
day_2 = now - timedelta(days=1)
yesterday = day_2.strftime("%Y%m%d")

def job():
    strDd=today
    endDd=today

    df = df.set_index('short_code')
    full_code = df.loc['005930']['full_code']

    data2={'bld': 'dbms/MDC/STAT/standard/MDCSTAT01701',
        'isuCd': full_code,
        'isuCd2': full_code,
        'strtDd': strDd,
        'endDd': endDd,
        'searchType':'2',
        'mktld':'ALL',
        'csvxls_isNo': 'false',
        'share': 1,
        'money': 1}


    url2="http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"

    r2=requests.post(url2, data2, headers)
    j2=json.loads(r2.text)
    df3=pd.DataFrame(j2['output'])

if df3.iloc[0,0]:
    break
else:
{ with open('df3.pickle','wb') as fw:
 pickle.dump(df3, fw)}

# %%
from datetime import datetime, timedelta
import schedule
import time
import json
import requests
import pandas as pd
import pickle
from os import path
from google.colab import drive 
from io import BytesIO
from datetime import datetime

schedule.every().day.at("24:00").do(job)

#날짜
now=datetime.now()
today=now.strftime("%Y%m%d")

day_1 = now + timedelta(days=1)
tomorrow = day_1.strftime("%Y%m%d")
day_2 = now - timedelta(days=1)
yesterday = day_2.strftime("%Y%m%d")

def job():
    headers={'User-Agent': 'Chrome/93.0.4577.63 Safari/537.36'}

    data={'mktId': 'ALL',
            'typeNo':'0',
            'searchText':'',
            'bld': 'dbms/comm/finder/finder_stkisu'}

    url="http://data.krx.co.kr/comm/bldAttendant/getJsonData.cmd"

    r=requests.post(url, data, headers=headers)
    j = json.loads(r.text)
    df_ex=pd.json_normalize(j['block1'])


i#f df_ex.iloc[0,0]:
  #  break
#else:
with open('df_ex.pickle','wb') as fw:
    pickle.dump(df_ex, fw)

# %%
# !git clone https://github.com/baeksumin/k-project.git
